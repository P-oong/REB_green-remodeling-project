# %%
import pandas as pd
import numpy as np
import os

# 파일 경로 설정
file_path = '../data/2023년_에너지소비량_보고 건축물_20250331.xlsx'

# %%
df = pd.read_excel(file_path, header=[3, 4], sheet_name='1_2023년_에너지사용량')
df.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',                    'Unnamed: 0_level_1'),
#             (             '건축물ID',                    'Unnamed: 1_level_1'),
#             (                '지역',                    'Unnamed: 2_level_1'),
#             (                '용도',                    'Unnamed: 3_level_1'),
#             (                '면적',                    'Unnamed: 4_level_1'),
#             (              '기관유형',                    'Unnamed: 5_level_1'),
#             (              '코드번호',                    'Unnamed: 6_level_1'),
#             (               '기관명',                    'Unnamed: 7_level_1'),
#             (              '건축물명',                    'Unnamed: 8_level_1'),
#             (                '주소',                    'Unnamed: 9_level_1'),
#             (               '연면적',                   'Unnamed: 10_level_1'),
#             (             '냉난방면적',                   'Unnamed: 11_level_1'),
#             (             '냉난방면적',                                    '지상'),
#             (             '냉난방면적',                                    '지하'),
#             (             '냉난방면적',                                '사용승인연도'),
#             (             '냉난방면적',                               '건축물 등록일'),
#             (             '냉난방면적',            '연간 단위면적당 1차 에너지 소비량 3개년 평균'),
#             (             '냉난방면적',        '연간 단위면적당 1차 에너지 소비량 3개년 평균 중간값'),
#             (             '냉난방면적', '간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 3개년 평균'),
#             (             '냉난방면적', '간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 2개년 평균'),
#             (             '냉난방면적', '간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 1개년 평균'),
#             (             '냉난방면적',                          '건축물 시설관리자 이름'),
#             (             '냉난방면적',                        '건축물 시설관리자  연락처'),
#             (             '냉난방면적',                     '건축물 에너지사용량 입력자 이름'),
#             (             '냉난방면적',                    '건축물 에너지사용량 입력자 연락처'),
#             (     '단위면적당 1차 E사용량',                              '전기 (KWH)'),
#             (     '단위면적당 1차 E사용량',                              '가스 (KWH)'),
#             (     '단위면적당 1차 E사용량',                           '지역냉난방 (KWH)'),
#             (     '단위면적당 1차 E사용량',                              '유류 (KWH)'),
#             (     '단위면적당 1차 E사용량',                              '기타 (KWH)'),
#             (   'EUI(1차E/냉난방 면적)',                   'Unnamed: 30_level_1'),
#             (      'EUI(1차E/연면적)',                   'Unnamed: 31_level_1'),
#             (              '준공년도',                   'Unnamed: 32_level_1'),
#             (        'E사용량 (kWh)',                              '전기 (KWH)'),
#             (        'E사용량 (kWh)',                              '가스 (KWH)'),
#             (        'E사용량 (kWh)',                           '지역냉난방 (KWH)'),
#             (        'E사용량 (kWh)',                              '유류 (KWH)'),
#             (        'E사용량 (kWh)',                              '기타 (KWH)'),
#             (        'E사용량 (toe)',                              '전기 (toe)'),
#             (        'E사용량 (toe)',                              '가스 (toe)'),
#             (        'E사용량 (toe)',                           '지역냉난방 (toe)'),
#             (        'E사용량 (toe)',                              '유류 (toe)'),
#             (        'E사용량 (toe)',                              '기타 (toe)'),
#             (    '온실가스 배출량(tCO2)',                                    '전기'),
#             (    '온실가스 배출량(tCO2)',                                    '가스'),
#             (    '온실가스 배출량(tCO2)',                                  '지역난방'),
#             (    '온실가스 배출량(tCO2)',                                    '유류'),
#             (    '온실가스 배출량(tCO2)',                                    '기타'),
#             (    '온실가스 배출량(tCO2)',                                    '총계')],
#            )

# %%
df
# Out:
#                   건축물ID                 지역                 용도  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
# 0                321371              중부1지역             교육연구시설
# 1                 84781              중부1지역             교육연구시설
# 2                774699              중부1지역             교육연구시설
# 3                 83861              중부2지역             교육연구시설
# 4               4821001              중부2지역             교육연구시설
# ...                 ...                ...                ...
# 4189            2301364               남부지역               운수시설
# 4190            1791444               남부지역               운수시설
# 4191            2301365               남부지역               운수시설
# 4192            1791443               남부지역               운수시설
# 4193            2301363               남부지역               운수시설
#
#                       면적               기관유형               코드번호  \
#       Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0      3,000㎡이상~5,000㎡미만        광역 및 지방자치단체          1042-0161
# 1     5,000㎡이상~10,000㎡미만        광역 및 지방자치단체          1043-0074
# 2     5,000㎡이상~10,000㎡미만        광역 및 지방자치단체           1043-246
# 3      3,000㎡이상~5,000㎡미만        광역 및 지방자치단체          2042-0031
# 4      3,000㎡이상~5,000㎡미만        광역 및 지방자치단체          2042-0065
# ...                  ...                ...                ...
# 4189           10,000㎡이상          지방공사 및 공단          3024-0002
# 4190           10,000㎡이상          지방공사 및 공단          3024-0004
# 4191           10,000㎡이상          지방공사 및 공단          3024-0005
# 4192           10,000㎡이상          지방공사 및 공단          3024-0006
# 4193           10,000㎡이상          지방공사 및 공단          3024-0008
#
#                     기관명               건축물명  \
#      Unnamed: 6_level_1 Unnamed: 7_level_1
# 0           강원특별자치도 춘천시         춘천시립청소년도서관
# 1               경기도 파주시          파주시립중앙도서관
# 2               경기도 오산시            오산중앙도서관
# 3               경기도 이천시            이천시립도서관
# 4           전북특별자치도 익산시              영등도서관
# ...                 ...                ...
# 4189             대구교통공사            월배차량기지2
# 4190             광주교통공사            용산차량기지2
# 4191             대구교통공사            월배차량기지3
# 4192             광주교통공사            용산차량기지1
# 4193             대구교통공사            월배차량기지1
#
#                                                      주소                연면적  \
#                                      Unnamed: 8_level_1 Unnamed: 9_level_1
# 0     강원특별자치도 춘천시 옛경춘로 830-24(삼천동 28-79번지, 춘천시립청소년도서...            4676.20
# 1                                       경기도 파주시 금촌동 995            6515.94
# 2              경기도 오산시 운암로 85(오산동 920-3번지, 오산시 중앙도서관 )             6459.00
# 3                                     경기도 이천시 창전동 335-9            3297.88
# 4                                   전북특별자치도 익산시 영등동 814            3958.00
# ...                                                 ...                ...
# 4189                                  대구광역시 달서구 유천동 281           11236.23
# 4190                               광주광역시 동구 용산동 1-1 검사고           12482.10
# 4191                                  대구광역시 달서구 유천동 281           13570.21
# 4192                               광주광역시 동구 용산동 1-1 정비고           16365.55
# 4193                                  대구광역시 달서구 유천동 281           25212.25
#
#       ... E사용량 (toe)                               온실가스 배출량(tCO2)            \
#       ...   가스 (toe) 지역냉난방 (toe) 유류 (toe) 기타 (toe)             전기        가스
# 0     ...   0.126335    0.011461      0.0      0.0            0.0  0.295493
# 1     ...   0.179628    0.018365      0.0      0.0            0.0  0.420144
# 2     ...   0.048954    0.027396      0.0      0.0            0.0  0.114502
# 3     ...   0.065093    0.000000      0.0      0.0            0.0  0.152251
# 4     ...   0.046391    0.005530      0.0      0.0            0.0  0.108508
# ...   ...        ...         ...      ...      ...            ...       ...
# 4189  ...   0.148539    0.045817      0.0      0.0            0.0  0.347429
# 4190  ...   0.065626    0.006618      0.0      0.0            0.0  0.153498
# 4191  ...   0.256058    0.083116      0.0      0.0            0.0  0.598913
# 4192  ...   0.073207    0.020046      0.0      0.0            0.0  0.171230
# 4193  ...   0.034034    0.011484      0.0      0.0            0.0  0.079604
#
#
#           지역난방   유류   기타        총계
# 0     0.028556  0.0  0.0  0.324049
# 1     0.045757  0.0  0.0  0.465901
# 2     0.068260  0.0  0.0  0.182762
# 3     0.000000  0.0  0.0  0.152251
# 4     0.013778  0.0  0.0  0.122286
# ...        ...  ...  ...       ...
# 4189  0.114156  0.0  0.0  0.461585
# 4190  0.016490  0.0  0.0  0.169988
# 4191  0.207089  0.0  0.0  0.806002
# 4192  0.049946  0.0  0.0  0.221176
# 4193  0.028614  0.0  0.0  0.108217
#
# [4194 rows x 48 columns]

# %%
# 각 컬럼에 대해 헤더1에 'Unnamed'가 포함되어 있으면 헤더0만 사용, 그렇지 않으면 헤더0과 헤더1을 합칩니다.
df.columns = [
    col[0] if "Unnamed" in str(col[1]) else f"{col[0]}_{col[1]}"
    for col in df.columns
]

# 결과 확인
df.columns
# Out:
# Index(['Unnamed: 0_level_0', '건축물ID', '지역', '용도', '면적', '기관유형', '코드번호', '기관명',
#        '건축물명', '주소', '연면적', '냉난방면적', '냉난방면적_지상', '냉난방면적_지하', '냉난방면적_사용승인연도',
#        '냉난방면적_건축물 등록일', '냉난방면적_연간 단위면적당 1차 에너지 소비량 3개년 평균',
#        '냉난방면적_연간 단위면적당 1차 에너지 소비량 3개년 평균 중간값',
#        '냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 3개년 평균',
#        '냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 2개년 평균',
#        '냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 1개년 평균', '냉난방면적_건축물 시설관리자 이름',
#        '냉난방면적_건축물 시설관리자  연락처', '냉난방면적_건축물 에너지사용량 입력자 이름',
#        '냉난방면적_건축물 에너지사용량 입력자 연락처', '단위면적당 1차 E사용량_전기 (KWH)',
#        '단위면적당 1차 E사용량_가스 (KWH)', '단위면적당 1차 E사용량_지역냉난방 (KWH)',
#        '단위면적당 1차 E사용량_유류 (KWH)', '단위면적당 1차 E사용량_기타 (KWH)', 'EUI(1차E/냉난방 면적)',
#        'EUI(1차E/연면적)', '준공년도', 'E사용량 (kWh)_전기 (KWH)', 'E사용량 (kWh)_가스 (KWH)',
#        'E사용량 (kWh)_지역냉난방 (KWH)', 'E사용량 (kWh)_유류 (KWH)', 'E사용량 (kWh)_기타 (KWH)',
#        'E사용량 (toe)_전기 (toe)', 'E사용량 (toe)_가스 (toe)', 'E사용량 (toe)_지역냉난방 (toe)',
#        'E사용량 (toe)_유류 (toe)', 'E사용량 (toe)_기타 (toe)', '온실가스 배출량(tCO2)_전기',
#        '온실가스 배출량(tCO2)_가스', '온실가스 배출량(tCO2)_지역난방', '온실가스 배출량(tCO2)_유류',
#        '온실가스 배출량(tCO2)_기타', '온실가스 배출량(tCO2)_총계'],
#       dtype='object')

# %%
df['E사용량 (kWh)_전기 (KWH)']
# Out:
# 0       193022.977933
# 1       767095.018000
# 2       654514.967225
# 3       278211.996364
# 4       421885.004698
#             ...
# 4189    399051.986836
# 4190    536110.992903
# 4191    468452.017943
# 4192    715551.100441
# 4193    867505.998400
# Name: E사용량 (kWh)_전기 (KWH), Length: 4194, dtype: float64

# %%
import pandas as pd

# 엑셀 파일 읽기
df_1 = pd.read_excel("../data/text_matching_result_ver3.xlsx")

# 필터링할 MATCH_STAGE 값 리스트
filter_values = [
    '1차', 
    '2차', 
    '3차', 
    '4차(DONG일치)', 
    '수동매칭(1차중복)', 
    '수동매칭(2차중복)', 
    '수동매칭(DONG일치)'
]

# MATCH_STAGE 컬럼의 값이 filter_values 리스트에 포함된 행만 필터링
filtered_df = df_1[df_1['MATCH_STAGE'].isin(filter_values)]

# 결과 확인
filtered_df
# Out:
#               SEQ_NO                      RECAP_PK       연면적     사용승인연도  \
# 0                972                     11110-900  10787.40 1971-04-21
# 1                974                     11110-900   5458.12 1991-07-22
# 3                976                     41480-189  10615.97 1999-08-26
# 9               2676               30200-100183053  16187.57 1990-12-01
# 12              2679                   27260-12720   3498.03 2000-08-01
# ...              ...                           ...       ...        ...
# 4183  10000004803212  27200-1000000000000001483139   4006.00 1983-10-26
# 4184  10000004803213  27200-1000000000000001483139  12569.13 2008-06-30
# 4185  10000004803214  27200-1000000000000001483139   7331.00 2001-07-16
# 4186  10000004803215  27200-1000000000000001483139   3919.28 1977-06-30
# 4187  10000004803234                   27200-18045   3877.20 2003-01-01
#
#             기관명                 건축물명  \
# 0           감사원                   본관
# 1           감사원            제2별관(제5호)
# 3           감사원      감사교육원(감사교육원 청사)
# 9     과학기술정보통신부  국립중앙과학관(과학기술전시체험센터)
# 12    과학기술정보통신부         중앙전파관리소 대구청사
# ...         ...                  ...
# 4183    대구교육대학교                 대학본부
# 4184    대구교육대학교        교사교육센터(상록교육관)
# 4185    대구교육대학교         제1강의동(인문사회관)
# 4186    대구교육대학교                  도서관
# 4187    대구교육대학교                 상록서재
#
#                                                      주소    지상    지하   TOTAREA  \
# 0                                       서울특별시 종로구 25-23   8.0   2.0  10787.40
# 1                                       서울특별시 종로구 25-23   2.0   3.0   5458.12
# 3                                               경기도 파주시   4.0   1.0  10615.97
# 9          대전광역시 유성구 대덕대로 481(구성동 32-2번지, 과학기술전시체험센터 )    4.0   1.0   6278.21
# 12                                 대구광역시 수성구 만촌동 1429-7   3.0   1.0   3498.03
# ...                                                 ...   ...   ...       ...
# 4183          대구광역시 남구 (대명동 1797-5번지, 대구교육대학교 1.대학본부 )    5.0   1.0   4018.80
# 4184  대구광역시 남구 중앙대로 219(대명동 1797-5번지, 대구교육대학교 15.교사교...   1.0  11.0  13695.58
# 4185  대구광역시 남구 중앙대로 219(대명동 1797-5번지, 대구교육대학교 3.제1강의...   5.0   1.0   7331.01
# 4186   대구광역시 남구 중앙대로 219(대명동 1797-5번지, 대구교육대학교 7.도서관 )    4.0   NaN   3919.28
# 4187                    대구광역시 남구 도촌길 37(대명동 1636-1번지 )   13.0   1.0   3877.20
#
#       ... BD_COUNT EBD_OVER_BD MATCH_TOKEN_COUNT  \
# 0     ...      5.0          no               NaN
# 1     ...      5.0          no               NaN
# 3     ...      4.0          no               NaN
# 9     ...     12.0          no               1.0
# 12    ...      1.0          no               NaN
# ...   ...      ...         ...               ...
# 4183  ...     24.0          no               1.0
# 4184  ...     24.0          no               1.0
# 4185  ...     24.0          no               1.0
# 4186  ...     24.0          no               NaN
# 4187  ...      1.0          no               NaN
#
#                                 ebd_unified_tokens                건축물명_tokens  \
# 0                                              NaN                        NaN
# 1                                              NaN                        NaN
# 3                                              NaN                        NaN
# 9          ['과학기술전시체험센터', '구성동', '국립중앙과학관', '2번지']  ['국립중앙과학관', '과학기술전시체험센터']
# 12                                             NaN                        NaN
# ...                                            ...                        ...
# 4183                    ['5번지', '대구교육대학교', '대학본부']                   ['대학본부']
# 4184  ['교사교육센터', '5번지', '대구교육대학교', '대명동', '상록교육관']        ['교사교육센터', '상록교육관']
# 4185   ['제1강의동', '5번지', '대구교육대학교', '대명동', '인문사회관']         ['제1강의동', '인문사회관']
# 4186                                           NaN                        NaN
# 4187                                           NaN                        NaN
#
#                                 주소_tokens  BLD_NM_tokens  DONG_NM_tokens  \
# 0                                     NaN            NaN             NaN
# 1                                     NaN            NaN             NaN
# 3                                     NaN            NaN             NaN
# 9            ['구성동', '2번지', '과학기술전시체험센터']        ['nan']  ['과학기술전시체험센터']
# 12                                    NaN            NaN             NaN
# ...                                   ...            ...             ...
# 4183           ['5번지', '대구교육대학교', '대학본부']    ['대구교육대학교']        ['대학본부']
# 4184  ['대명동', '5번지', '대구교육대학교', '교사교육센터']    ['대구교육대학교']       ['상록교육관']
# 4185   ['대명동', '5번지', '대구교육대학교', '제1강의동']    ['대구교육대학교']       ['인문사회관']
# 4186                                  NaN            NaN             NaN
# 4187                                  NaN            NaN             NaN
#
#      MATCHED_BLD_TOKENS  MATCHED_DONG_TOKENS
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 3                   NaN                  NaN
# 9                    []       ['과학기술전시체험센터']
# 12                  NaN                  NaN
# ...                 ...                  ...
# 4183                 []             ['대학본부']
# 4184                 []            ['상록교육관']
# 4185                 []            ['인문사회관']
# 4186                NaN                  NaN
# 4187                NaN                  NaN
#
# [3038 rows x 27 columns]

# %%
df = df.sort_values(by='건축물ID')
df
# Out:
#       Unnamed: 0_level_0           건축물ID     지역         용도  \
# 1855                 NaN             972  중부2지역       업무시설
# 1740                 NaN             974  중부2지역       업무시설
# 1643                 NaN             975  중부2지역       업무시설
# 1558                 NaN             976  중부1지역       업무시설
# 3920                 NaN            1861  중부2지역  문화 및 집회시설
# ...                  ...             ...    ...        ...
# 1887                 NaN  10000006164722  중부2지역       업무시설
# 1664                 NaN  10000006164723  중부2지역       업무시설
# 1888                 NaN  10000006164724  중부2지역       업무시설
# 1889                 NaN  10000006164725  중부2지역       업무시설
# 1890                 NaN  10000006164726  중부2지역       업무시설
#
#                       면적           기관유형       코드번호            기관명  \
# 1855           10,000㎡이상  중앙행정기관 및 소속기관  2064-0133            감사원
# 1740  5,000㎡이상~10,000㎡미만  중앙행정기관 및 소속기관  2063-0216            감사원
# 1643   3,000㎡이상~5,000㎡미만  중앙행정기관 및 소속기관  2062-0276            감사원
# 1558           10,000㎡이상  중앙행정기관 및 소속기관  1064-0132            감사원
# 3920   3,000㎡이상~5,000㎡미만  중앙행정기관 및 소속기관  2012-0038            교육부
# ...                  ...            ...        ...            ...
# 1887           10,000㎡이상  중앙행정기관 및 소속기관   2064-321  정부청사관리본부 세종청사
# 1664   3,000㎡이상~5,000㎡미만  중앙행정기관 및 소속기관   2062-393  정부청사관리본부 세종청사
# 1888           10,000㎡이상  중앙행정기관 및 소속기관   2064-322  정부청사관리본부 세종청사
# 1889           10,000㎡이상  중앙행정기관 및 소속기관   2064-323  정부청사관리본부 세종청사
# 1890           10,000㎡이상  중앙행정기관 및 소속기관   2064-324  정부청사관리본부 세종청사
#
#                  건축물명                                          주소  ...  \
# 1855               본관                             서울특별시 종로구 25-23  ...
# 1740        제2별관(제5호)                             서울특별시 종로구 25-23  ...
# 1643   제3별관(감사원 제2별관)                                   서울특별시 종로구  ...
# 1558  감사교육원(감사교육원 청사)                                     경기도 파주시  ...
# 3920          대한민국학술원                      서울특별시 서초구 반포동 94-4 학술원  ...
# ...               ...                                         ...  ...
# 1887        정부세종청사 2동  세종특별자치도 세종특별자치시 (어진동 3-187번지, 정부세종청사 2동 )   ...
# 1664        정부세종청사 3동  세종특별자치도 세종특별자치시 (어진동 3-187번지, 정부세종청사 3동 )   ...
# 1888        정부세종청사 4동  세종특별자치도 세종특별자치시 (어진동 3-187번지, 정부세종청사 4동 )   ...
# 1889        정부세종청사 5동  세종특별자치도 세종특별자치시 (어진동 3-187번지, 정부세종청사 5동 )   ...
# 1890        정부세종청사 6동  세종특별자치도 세종특별자치시 (어진동 3-187번지, 정부세종청사 6동 )   ...
#
#       E사용량 (toe)_가스 (toe)  E사용량 (toe)_지역냉난방 (toe)  E사용량 (toe)_유류 (toe)  \
# 1855            86.940550                0.000000                  0.0
# 1740            24.847132                0.000000                  0.0
# 1643            18.299758                0.000000                  0.0
# 1558            35.946630                0.000000                  0.0
# 3920            11.189089                0.000000                  0.0
# ...                   ...                     ...                  ...
# 1887             7.850583               66.999620                  0.0
# 1664             1.296711               10.563942                  0.0
# 1888            10.293459               87.857574                  0.0
# 1889            13.643916              116.439827                  0.0
# 1890            16.924408              144.447371                  0.0
#
#       E사용량 (toe)_기타 (toe) 온실가스 배출량(tCO2)_전기 온실가스 배출량(tCO2)_가스  \
# 1855                  0.0        469.016292        203.351319
# 1740                  0.0        103.264900         58.116692
# 1643                  0.0         94.568871         42.802580
# 1558                  0.0        321.707233         84.078082
# 3920                  0.0         82.815696         26.170941
# ...                   ...               ...               ...
# 1887                  0.0       1642.195415         18.362277
# 1664                  0.0        258.932911          3.032968
# 1888                  0.0       2153.429498         24.076088
# 1889                  0.0       2853.998216         31.912707
# 1890                  0.0       3540.479981         39.585678
#
#      온실가스 배출량(tCO2)_지역난방  온실가스 배출량(tCO2)_유류  온실가스 배출량(tCO2)_기타  \
# 1855            0.000000                0.0                0.0
# 1740            0.000000                0.0                0.0
# 1643            0.000000                0.0                0.0
# 1558            0.000000                0.0                0.0
# 3920            0.000000                0.0                0.0
# ...                  ...                ...                ...
# 1887          166.933888                0.0                0.0
# 1664           26.320745                0.0                0.0
# 1888          218.902828                0.0                0.0
# 1889          290.117360                0.0                0.0
# 1890          359.899967                0.0                0.0
#
#       온실가스 배출량(tCO2)_총계
# 1855         672.367611
# 1740         161.381592
# 1643         137.371452
# 1558         405.785315
# 3920         108.986637
# ...                 ...
# 1887        1827.491579
# 1664         288.286624
# 1888        2396.408414
# 1889        3176.028283
# 1890        3939.965626
#
# [4194 rows x 49 columns]

# %%
# Unnamed: 0_level_0 컬럼 제거
df = df.drop('Unnamed: 0_level_0', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4194 entries, 1855 to 1890
# Data columns (total 48 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   건축물ID                                        4194 non-null   int64
#  1   지역                                           4194 non-null   object
#  2   용도                                           4194 non-null   object
#  3   면적                                           4194 non-null   object
#  4   기관유형                                         4194 non-null   object
#  5   코드번호                                         4194 non-null   object
#  6   기관명                                          4194 non-null   object
#  7   건축물명                                         4194 non-null   object
#  8   주소                                           4194 non-null   object
#  9   연면적                                          4194 non-null   float64
#  10  냉난방면적                                        4194 non-null   float64
#  11  냉난방면적_지상                                     4189 non-null   float64
#  12  냉난방면적_지하                                     4028 non-null   float64
#  13  냉난방면적_사용승인연도                                 4194 non-null   object
#  14  냉난방면적_건축물 등록일                                4194 non-null   object
#  15  냉난방면적_연간 단위면적당 1차 에너지 소비량 3개년 평균             4194 non-null   object
#  16  냉난방면적_연간 단위면적당 1차 에너지 소비량 3개년 평균 중간값         0 non-null      float64
#  17  냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 3개년 평균  0 non-null      float64
#  18  냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 2개년 평균  0 non-null      float64
#  19  냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 1개년 평균  0 non-null      float64
#  20  냉난방면적_건축물 시설관리자 이름                           4110 non-null   object
#  21  냉난방면적_건축물 시설관리자  연락처                         4110 non-null   object
#  22  냉난방면적_건축물 에너지사용량 입력자 이름                      4110 non-null   object
#  23  냉난방면적_건축물 에너지사용량 입력자 연락처                     4110 non-null   object
#  24  단위면적당 1차 E사용량_전기 (KWH)                       4194 non-null   float64
#  25  단위면적당 1차 E사용량_가스 (KWH)                       4194 non-null   float64
#  26  단위면적당 1차 E사용량_지역냉난방 (KWH)                    4194 non-null   float64
#  27  단위면적당 1차 E사용량_유류 (KWH)                       4194 non-null   float64
#  28  단위면적당 1차 E사용량_기타 (KWH)                       4194 non-null   float64
#  29  EUI(1차E/냉난방 면적)                              4194 non-null   float64
#  30  EUI(1차E/연면적)                                 4194 non-null   float64
#  31  준공년도                                         4194 non-null   int64
#  32  E사용량 (kWh)_전기 (KWH)                          4194 non-null   float64
#  33  E사용량 (kWh)_가스 (KWH)                          4194 non-null   float64
#  34  E사용량 (kWh)_지역냉난방 (KWH)                       4194 non-null   float64
#  35  E사용량 (kWh)_유류 (KWH)                          4194 non-null   float64
#  36  E사용량 (kWh)_기타 (KWH)                          4194 non-null   float64
#  37  E사용량 (toe)_전기 (toe)                          4194 non-null   float64
#  38  E사용량 (toe)_가스 (toe)                          4194 non-null   float64
#  39  E사용량 (toe)_지역냉난방 (toe)                       4194 non-null   float64
#  40  E사용량 (toe)_유류 (toe)                          4194 non-null   float64
#  41  E사용량 (toe)_기타 (toe)                          4194 non-null   float64
#  42  온실가스 배출량(tCO2)_전기                            4194 non-null   float64
#  43  온실가스 배출량(tCO2)_가스                            4194 non-null   float64
#  44  온실가스 배출량(tCO2)_지역난방                          4194 non-null   float64
#  45  온실가스 배출량(tCO2)_유류                            4194 non-null   float64
#  46  온실가스 배출량(tCO2)_기타                            4194 non-null   float64
#  47  온실가스 배출량(tCO2)_총계                            4194 non-null   float64
# dtypes: float64(31), int64(2), object(15)
# memory usage: 1.6+ MB

# %%
import pandas as pd

# 1. 에너지 데이터에서 필요한 컬럼 리스트 (건축물ID 포함)
energy_vars = [
    '단위면적당 1차 E사용량_전기 (KWH)',
    '단위면적당 1차 E사용량_가스 (KWH)',
    '단위면적당 1차 E사용량_지역냉난방 (KWH)',
    '단위면적당 1차 E사용량_유류 (KWH)',
    '단위면적당 1차 E사용량_기타 (KWH)',
    'EUI(1차E/냉난방 면적)',
    'EUI(1차E/연면적)',
    '준공년도',
    'E사용량 (kWh)_전기 (KWH)',
    'E사용량 (kWh)_가스 (KWH)',
    'E사용량 (kWh)_지역냉난방 (KWH)',
    'E사용량 (kWh)_유류 (KWH)',
    'E사용량 (kWh)_기타 (KWH)',
    'E사용량 (toe)_전기 (toe)',
    'E사용량 (toe)_가스 (toe)',
    'E사용량 (toe)_지역냉난방 (toe)',
    'E사용량 (toe)_유류 (toe)',
    'E사용량 (toe)_기타 (toe)',
    '온실가스 배출량(tCO2)_전기',
    '온실가스 배출량(tCO2)_가스',
    '온실가스 배출량(tCO2)_지역난방',
    '온실가스 배출량(tCO2)_유류',
    '온실가스 배출량(tCO2)_기타',
    '온실가스 배출량(tCO2)_총계'
]

# 에너지 데이터에서 '건축물ID'와 위 변수들만 선택
energy_subset = df[['건축물ID'] + energy_vars]

# 2. filtered_df (텍스트 매칭 결과)와 energy_subset을 건축물ID 기준으로 왼쪽 병합(merge)
merged_df = pd.merge(filtered_df, energy_subset, left_on='SEQ_NO', right_on='건축물ID', how='left')

# 3. 병합 결과에서 에너지 데이터가 붙은 건수를 파악합니다.
# 에너지 데이터가 붙지 않은 경우, energy_vars에 해당하는 컬럼들은 모두 NaN으로 남게 됩니다.
# 여기서는 첫번째 에너지 변수('단위면적당 1차 E사용량_전기 (KWH)')가 NaN이 아닌 경우를 매칭된 것으로 판단합니다.
matched_count = merged_df['단위면적당 1차 E사용량_전기 (KWH)'].notna().sum()
total_count = merged_df.shape[0]
unmatched_count = total_count - matched_count

print(f"총 {total_count}건 중, {matched_count}건이 건축물ID 기준으로 에너지 데이터와 매칭되었습니다.")
print(f"{unmatched_count}건은 건축물ID가 없어 에너지 데이터와 매칭되지 않았습니다.")
# Out:
# 총 3038건 중, 3038건이 건축물ID 기준으로 에너지 데이터와 매칭되었습니다.
# 0건은 건축물ID가 없어 에너지 데이터와 매칭되지 않았습니다.

# %%
# 엑셀 파일로 저장
merged_df.to_excel('../result/merged_energy_data_new.xlsx', index=False)
print("엑셀 파일이 성공적으로 저장되었습니다.")
# Out:
# 엑셀 파일이 성공적으로 저장되었습니다.

# %%
# 엑셀 파일로 저장
df.to_excel('../result/raw23_energy_data_new.xlsx', index=False)
print("엑셀 파일이 성공적으로 저장되었습니다.")
# Out:
# 엑셀 파일이 성공적으로 저장되었습니다.

# %%
df.columns
# Out:
# Index(['건축물ID', '지역', '용도', '면적', '기관유형', '코드번호', '기관명', '건축물명', '주소', '연면적',
#        '냉난방면적', '냉난방면적_지상', '냉난방면적_지하', '냉난방면적_사용승인연도', '냉난방면적_건축물 등록일',
#        '냉난방면적_연간 단위면적당 1차 에너지 소비량 3개년 평균',
#        '냉난방면적_연간 단위면적당 1차 에너지 소비량 3개년 평균 중간값',
#        '냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 3개년 평균',
#        '냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 2개년 평균',
#        '냉난방면적_간절기 대비 소비량 비율[(냉방월 +난방월)/간절기월] 1개년 평균', '냉난방면적_건축물 시설관리자 이름',
#        '냉난방면적_건축물 시설관리자  연락처', '냉난방면적_건축물 에너지사용량 입력자 이름',
#        '냉난방면적_건축물 에너지사용량 입력자 연락처', '단위면적당 1차 E사용량_전기 (KWH)',
#        '단위면적당 1차 E사용량_가스 (KWH)', '단위면적당 1차 E사용량_지역냉난방 (KWH)',
#        '단위면적당 1차 E사용량_유류 (KWH)', '단위면적당 1차 E사용량_기타 (KWH)', 'EUI(1차E/냉난방 면적)',
#        'EUI(1차E/연면적)', '준공년도', 'E사용량 (kWh)_전기 (KWH)', 'E사용량 (kWh)_가스 (KWH)',
#        'E사용량 (kWh)_지역냉난방 (KWH)', 'E사용량 (kWh)_유류 (KWH)', 'E사용량 (kWh)_기타 (KWH)',
#        'E사용량 (toe)_전기 (toe)', 'E사용량 (toe)_가스 (toe)', 'E사용량 (toe)_지역냉난방 (toe)',
#        'E사용량 (toe)_유류 (toe)', 'E사용량 (toe)_기타 (toe)', '온실가스 배출량(tCO2)_전기',
#        '온실가스 배출량(tCO2)_가스', '온실가스 배출량(tCO2)_지역난방', '온실가스 배출량(tCO2)_유류',
#        '온실가스 배출량(tCO2)_기타', '온실가스 배출량(tCO2)_총계'],
#       dtype='object')
